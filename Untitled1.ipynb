# %%
import pandas as pd

# Load dataset
df = pd.read_csv("combined_data.csv")

# Explore data
print("First 5 Rows:")
print(df.head())

print("\nShape:")
print(df.shape)

print("\nColumns:")
print(df.columns)

print("\nData Types:")
print(df.dtypes)

# Check missing values
print("\nMissing Values:")
print(df.isnull().sum())

# Fill missing values
for col in df.select_dtypes(include=['number']).columns:
    df[col].fillna(df[col].mean(), inplace=True)

for col in df.select_dtypes(include=['object']).columns:
    df[col].fillna(df[col].mode()[0], inplace=True)

# Remove duplicates
df = df.drop_duplicates()

# Select columns (example)
print("\nSelected Columns:")
print(df[['price', 'quantity']].head())

# Filter rows (example)
filtered_df = df[df['price'] > 100]
print("\nFiltered Data:")
print(filtered_df.head())

# Create derived column
df['total_amount'] = df['price'] * df['quantity']

# Save cleaned dataset
df.to_csv("cleaned_combined_data.csv", index=False)

print("\nDataset cleaned and saved successfully!")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[1], line 4
#       1 import pandas as pd
#       3 # Load dataset
# ----> 4 df = pd.read_csv("combined_data.csv")
#       6 # Explore data
#       7 print("First 5 Rows:")
#
# ...

# %%
import os
print(os.getcwd())
print(os.listdir())
# Out:
# C:\Users\SUBHA PRAYASH
# ['-1.14-windows.xml', '.anaconda', '.bash_history', '.conda', '.continuum', '.copilot', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.TurboVPN', '.vscode', 'anaconda_projects', 'ansel', 'AppData', 'Application Data', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'html', 'Links', 'Local Settings', 'MOVIE', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{970ff345-5cd6-11f0-96a2-e3faaf0baeb4}.TM.blf', 'NTUSER.DAT{970ff345-5cd6-11f0-96a2-e3faaf0baeb4}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{970ff345-5cd6-11f0-96a2-e3faaf0baeb4}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Videos']

# %%
import os

for file in os.listdir("Downloads"):
    if file.endswith(".csv"):
        print(file)
# Out:
# Combined_dataset.csv

# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\SUBHA PRAYASH\Downloads\Combined_dataset.csv")

print(df.head())
print(df.columns)
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %%
# Missing values
print(df.isnull().sum())

# Remove duplicates
df = df.drop_duplicates()

# Create derived column
df['discount_amount'] = df['initial_price'] - df['final_price']

# Filter rows
filtered_df = df[df['rating'] > 4.0]
print(filtered_df[['title','rating']].head())

# Save cleaned dataset
df.to_csv("cleaned_combined_dataset.csv", index=False)

print("Dataset cleaned and saved successfully!")
# Out:
# product_id                  0
# title                       0
# product_description         0
# rating                      0
# ratings_count               0
# initial_price               0
# discount                  121
# final_price                 0
# currency                    0
# images                      0
# delivery_options            0
# product_details             0
# breadcrumbs                 0
# product_specifications      0
# amount_of_stars             0
# what_customers_said       573
# seller_name               301
# sizes                       0
# videos                    781
# seller_information        301
# variations                562
# best_offer                  0
# more_offers                 0
# category                    0
# dtype: int64
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...

# %%
# Remove duplicates
df = df.drop_duplicates()

# Create derived column
df["rating_plus_reviews"] = df["rating"] + df["ratings_count"]

# Filter rows
filtered_df = df[df["rating"] > 4.0]
print(filtered_df[["title","rating"]].head())

# Save cleaned dataset
df.to_csv("cleaned_combined_dataset.csv", index=False)

print("Dataset cleaned and saved successfully!")
# Out:
#             title  rating
# 1  Tommy Hilfiger     4.5
# 2           Lavie     4.4
# 3          F Gear     4.4
# 4       MYTRIDENT     4.7
# 5             H&M     4.5
# Dataset cleaned and saved successfully!

# %%
import os 
print(os.listdir())
# Out:
# ['-1.14-windows.xml', '.anaconda', '.bash_history', '.conda', '.continuum', '.copilot', '.gitconfig', '.ipynb_checkpoints', '.ipython', '.jupyter', '.TurboVPN', '.vscode', 'anaconda_projects', 'ansel', 'AppData', 'Application Data', 'cleaned_combined_dataset.csv', 'Contacts', 'Cookies', 'Desktop', 'Documents', 'Downloads', 'Favorites', 'html', 'Links', 'Local Settings', 'MOVIE', 'Music', 'My Documents', 'NetHood', 'NTUSER.DAT', 'ntuser.dat.LOG1', 'ntuser.dat.LOG2', 'NTUSER.DAT{970ff345-5cd6-11f0-96a2-e3faaf0baeb4}.TM.blf', 'NTUSER.DAT{970ff345-5cd6-11f0-96a2-e3faaf0baeb4}.TMContainer00000000000000000001.regtrans-ms', 'NTUSER.DAT{970ff345-5cd6-11f0-96a2-e3faaf0baeb4}.TMContainer00000000000000000002.regtrans-ms', 'ntuser.ini', 'OneDrive', 'Pictures', 'PrintHood', 'Recent', 'Saved Games', 'Searches', 'SendTo', 'Start Menu', 'Templates', 'Untitled.ipynb', 'Untitled1.ipynb', 'Videos']
